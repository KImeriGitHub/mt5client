# %%
import sys
import os

project_dir = os.path.abspath("..")
if project_dir not in sys.path:
    sys.path.append(project_dir)

import polars as pl
import MetaTrader5 as mt5
from src.infra.mtBase import mtBase
from src.infra.PredictionParser import PredictionParser, PredictionData

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

now = datetime.now(ZoneInfo("Europe/Zurich"))
print(now)
# Out:
# 2025-12-04 17:27:17.003103+01:00

# %%
from src.infra.TimeModule import TimeModule
import time
tm = TimeModule()  # defaults to Europe/Zurich
sec_to_wait = tm.calc_sec_to_sleep(17, 35)

print(f"Sleeping for {sec_to_wait} seconds...")
time.sleep(sec_to_wait)

print("Target time reached!")
# Out:
# Sleeping for 460.105248 seconds...
